# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
meritve = {
    0: [
        (-20, 0.77, 0.74),
        (-15, 1.01, 1.01),
        (-10, 1.44, 1.4),
        (-8, 1.84, 1.84),
        (-6, 2.36, 2.38),
        (-5, 2.70, 2.70),
        (-4, 3.32, 3.44),
        (-3, 4.16, 4.4),
        (-2, 5.96, 5.72),
        (-1, 8.48, 8.72),
        (-0.5, 10.2, 11.8),
        (0, 13.8, 16.6),
        (0.5, 17.2, 16.4),
        (1, 16.2, 14.0),
        (2, 9.2, 8.4),
        (3, 5.76, 5.24),
        (5, 3.24, 3.08),
        (7, 2.30, 2.22),
        (10, 1.54, 1.46),
        (15, 1.02, 1.00),
        (20, 0.77, 0.74)
    ],
    5: [
        (0, 0.76),
        (5, 1.02),
        (10, 1.40),
        (15, 2.72),
        (16, 3.14),
        (17, 3.76),
        (18, 4.6),
        (19, 6.0),
        (19.5, 6.52),
        (20, 6.92),
        (20.5, 6.96),
        (21, 6.76),
        (22, 5.60),
        (23, 4.6),
        (24, 3.54),
        (30, 1.50),
        (35, 1.0),
        (40, 0.74)
    ],
    10: [
        (0, 0.74),
        (5, 0.97),
        (10, 1.43),
        (15, 2.46),
        (16, 2.72),
        (17, 3.02),
        (18, 3.62),
        (19, 4.04),
        (19.5, 4.36),
        (20, 4.44),
        (20.5, 4.36),
        (21, 4.28),
        (22, 3.96),
        (23, 3.64),
        (24, 3.00),
        (25, 2.76),
        (30, 2.04),
        (35, 1.40),
        (40, 0.97)
        ],
    20: [
        (0, 0.74),
        (5, 0.93),
        (10, 1.25),
        (15, 1.90),
        (16, 2.06),
        (17, 2.20),
        (18, 2.30),
        (19, 2.46),
        (19.5, 2.50),
        (20, 2.50),
        (20.5, 2.50),
        (21, 2.48),
        (22, 2.44),
        (23, 2.26),
        (24, 2.12),
        (25, 1.92),
        (30, 1.27),
        (35, 0.91),
        (40, 0.09)
    ]
}

meritve[0] = [(i[0] + 152, i[1]) for i in meritve[0]]
meritve[5] = [(i[0] + 132, i[1]) for i in meritve[5]]
meritve[10] = [(i[0] + 132, i[1]) for i in meritve[10]]
meritve[20] = [(i[0] + 132, i[1]) for i in meritve[20]]

# %%
colors = ['r', 'b', 'k', 'g']
plt.figure(figsize=(12,7))
for i, k in enumerate(meritve.keys()):
    x = [j[0] for j in meritve[k]]
    y = [j[1] for j in meritve[k]]
    plt.plot(x, y, colors[i] + '-o')
